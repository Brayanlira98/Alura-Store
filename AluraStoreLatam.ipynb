# %% [markdown]
# <a href="https://colab.research.google.com/github/Brayanlira98/Alura-Store/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Analisis de los datos:

# %% [markdown]
# ## Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# ##1. Análisis de facturación

# %%
print(f"Cantidad de filas y columnas en, tienda 1: {tienda.shape} tienda 2: {tienda2.shape} tienda 3: {tienda3.shape} tienda 4: {tienda4.shape}")
# Out:
# Cantidad de filas y columnas en, tienda 1: (2359, 12) tienda 2: (2359, 12) tienda 3: (2359, 12) tienda 4: (2358, 12)

# %%
a=(tienda.isnull().sum())
b=(tienda2.isnull().sum())
c=(tienda3.isnull().sum())
d=(tienda4.isnull().sum())
print(a,b,c,d)
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64 Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64 Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# ...

# %%
Ingreso_total_tienda_1=tienda.Precio.sum()
Ingreso_total_tienda_2=tienda2.Precio.sum()
Ingreso_total_tienda_3=tienda3.Precio.sum()
Ingreso_total_tienda_4=tienda4.Precio.sum()

print(f'Ingreso total tienda 1: {Ingreso_total_tienda_1}\nIngreso total tienda 2: {Ingreso_total_tienda_2}\nIngreso total tienda 3: {Ingreso_total_tienda_3}\nIngreso total tienda 4: {Ingreso_total_tienda_4} ')

Grafica=pd.DataFrame([['Tienda 1',Ingreso_total_tienda_1],['Tienda 2',Ingreso_total_tienda_2],['Tienda 3',Ingreso_total_tienda_3],['Tienda 4',Ingreso_total_tienda_4]],columns=['Tienda','Ingreso total'])
Grafica.plot(x='Tienda',kind='bar',color='green',xlabel='Tienda',ylabel='Ingreso',title='Ingreso total por tienda')
# Out:
# Ingreso total tienda 1: 1150880400.0
# Ingreso total tienda 2: 1116343500.0
# Ingreso total tienda 3: 1098019600.0
# Ingreso total tienda 4: 1038375700.0
# <Axes: title={'center': 'Ingreso total por tienda'}, xlabel='Tienda', ylabel='Ingreso'>

# %% [markdown]
# ## 2. Ventas por categoría

# %%
Ventas_por_categoria_tienda_1=tienda["Categoría del Producto"].value_counts()
Ventas_por_categoria_tienda_1.plot(kind='pie',color='red',ylabel='',title='Ventas por categoría: Tienda 1')
Ventas_por_categoria_tienda_1
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
Ventas_por_categoria_tienda_2=tienda2["Categoría del Producto"].value_counts()
Ventas_por_categoria_tienda_2.plot(kind='pie',color='red',ylabel='',title='Ventas por categoría: Tienda 2')
Ventas_por_categoria_tienda_2
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
Ventas_por_categoria_tienda_3=tienda3["Categoría del Producto"].value_counts()
Ventas_por_categoria_tienda_3.plot(kind='pie',color='red',ylabel='',title='Ventas por categoría: Tienda 3')
Ventas_por_categoria_tienda_3
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
Ventas_por_categoria_tienda_4=tienda4["Categoría del Producto"].value_counts()
Ventas_por_categoria_tienda_4.plot(kind='pie',color='red',ylabel='',title='Ventas por categoría: Tienda 4')
Ventas_por_categoria_tienda_4
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Calificación promedio de la tienda

# %%
Calificacion_Tienda_1=tienda['Calificación'].mean()
Calificacion_Tienda_2=tienda2['Calificación'].mean()
Calificacion_Tienda_3=tienda3['Calificación'].mean()
Calificacion_Tienda_4=tienda4['Calificación'].mean()

print(f"Calificación promedio de las tiendas\nTienda 1: {Calificacion_Tienda_1}\nTienda 2: {Calificacion_Tienda_2}\nTienda 3: {Calificacion_Tienda_3}\nTienda 4: {Calificacion_Tienda_4}")
Calificacion_promedio=pd.DataFrame([['Tienda 1',Calificacion_Tienda_1],['Tienda 2',Calificacion_Tienda_2],['Tienda 3',Calificacion_Tienda_3],['Tienda 4',Calificacion_Tienda_4]],columns=['Tienda','Calificación promedio'])
Calificacion_promedio.plot(x='Tienda',title='Calificación promedio de cada tienda',ylabel='Calificación',marker='o')
# Out:
# Calificación promedio de las tiendas
# Tienda 1: 3.976685036032217
# Tienda 2: 4.037303942348453
# Tienda 3: 4.048325561678677
# Tienda 4: 3.9957591178965224
# <Axes: title={'center': 'Calificación promedio de cada tienda'}, xlabel='Tienda', ylabel='Calificación'>

# %% [markdown]
# ## 4. Productos más y menos vendidos

# %%
Productos_tienda1=tienda['Producto'].value_counts()
Productos_tienda1.plot(kind='barh',figsize=(7,10),title='Cantidad de productos vendidos tienda 1',xlabel='Cantidad')
mas_vendidos_tienda1=Productos_tienda1.loc[lambda x:x==x.max()].to_frame()
menos_vendidos_tienda1=Productos_tienda1.loc[lambda x:x==x.min()].to_frame()
print("Productos menos vendidos tienda 1:\n",menos_vendidos_tienda1, "\n\nProductos más vendidos tienda 1:\n",mas_vendidos_tienda1)
# Out:
# Productos menos vendidos tienda 1:
#                             count
# Producto
# Auriculares con micrófono     33
# Celular ABXY                  33
#
# Productos más vendidos tienda 1:
#                 count
# Producto
# Microondas        60
# TV LED UHD 4K     60
# Armario           60

# %%
Productos_tienda2=tienda2['Producto'].value_counts()
Productos_tienda2.plot(kind='barh',figsize=(7,10),title='Cantidad de productos vendidos tienda 2',xlabel='Cantidad')
mas_vendidos_tienda2=Productos_tienda2.loc[lambda x:x==x.max()].to_frame()
menos_vendidos_tienda2=Productos_tienda2.loc[lambda x:x==x.min()].to_frame()
print("Productos menos vendidos tienda 2:\n",menos_vendidos_tienda2, "\n\nProductos más vendidos tienda 2:\n",mas_vendidos_tienda2)
# Out:
# Productos menos vendidos tienda 2:
#                 count
# Producto
# Juego de mesa     32
#
# Productos más vendidos tienda 2:
#                             count
# Producto
# Iniciando en programación     65

# %%
Productos_tienda3=tienda3['Producto'].value_counts()
Productos_tienda3.plot(kind='barh',figsize=(7,10),title='Cantidad de productos vendidos tienda 3',xlabel='Cantidad')
mas_vendidos_tienda3=Productos_tienda3.loc[lambda x:x==x.max()].to_frame()
menos_vendidos_tienda3=Productos_tienda3.loc[lambda x:x==x.min()].to_frame()
print("Productos menos vendidos tienda 3:\n",menos_vendidos_tienda3, "\n\nProductos más vendidos tienda 3:\n",mas_vendidos_tienda3)
# Out:
# Productos menos vendidos tienda 3:
#                           count
# Producto
# Bloques de construcción     35
#
# Productos más vendidos tienda 3:
#                 count
# Producto
# Kit de bancas     57

# %%
Productos_tienda4=tienda4['Producto'].value_counts()
Productos_tienda4.plot(kind='barh',figsize=(7,10),title='Cantidad de productos vendidos tienda 4',xlabel='Cantidad')
mas_vendidos_tienda4=Productos_tienda4.loc[lambda x:x==x.max()].to_frame()
menos_vendidos_tienda4=Productos_tienda4.loc[lambda x:x==x.min()].to_frame()
print("Productos menos vendidos tienda 4:\n",menos_vendidos_tienda4, "\n\nProductos más vendidos tienda 4:\n",mas_vendidos_tienda4)
# Out:
# Productos menos vendidos tienda 4:
#                      count
# Producto
# Guitarra eléctrica     33
#
# Productos más vendidos tienda 4:
#            count
# Producto
# Cama box     62

# %% [markdown]
# ## 5. Envío promedio por tienda

# %%
from numpy import tile
Envio_promedio_tienda1=tienda['Costo de envío'].mean()
Envio_promedio_tienda2=tienda2['Costo de envío'].mean()
Envio_promedio_tienda3=tienda3['Costo de envío'].mean()
Envio_promedio_tienda4=tienda4['Costo de envío'].mean()
Envio_promedio_por_tienda=pd.DataFrame([['Tienda 1',Envio_promedio_tienda1],['Tienda 2',Envio_promedio_tienda2],['Tienda 3',Envio_promedio_tienda3],['Tienda 4',Envio_promedio_tienda4]],columns=['Tienda','Costo de envío'])
Envio_promedio_por_tienda.plot(color='black',x='Tienda',ylabel='Costo',title='Costo de envío de cada tienda',marker='o')
Envio_promedio_por_tienda
# Out:
#      Tienda  Costo de envío
# 0  Tienda 1    26018.609580
# 1  Tienda 2    25216.235693
# 2  Tienda 3    24805.680373
# 3  Tienda 4    23459.457167

# %% [markdown]
# ##6. Análisis del desempeño geográfico

# %%
ubicacion_tienda1=tienda[['lat','lon']]
ubicacion_tienda1.plot(kind='scatter',x='lon',y='lat',ylabel='Latitud',xlabel='Longitud',title='Distribución geográfica de los productos vendidos: Tienda 1')
# Out:
# <Axes: title={'center': 'Distribución geográfica de los productos vendidos: Tienda 1'}, xlabel='Longitud', ylabel='Latitud'>

# %%
ubicacion_tienda2=tienda2[['lat','lon']]
ubicacion_tienda2.plot(kind='scatter',x='lon',y='lat',ylabel='Latitud',xlabel='Longitud',title='Distribución geográfica de los productos vendidos: Tienda 2')
# Out:
# <Axes: title={'center': 'Distribución geográfica de los productos vendidos: Tienda 2'}, xlabel='Longitud', ylabel='Latitud'>

# %%
ubicacion_tienda3=tienda3[['lat','lon']]
ubicacion_tienda3.plot(kind='scatter',x='lon',y='lat',ylabel='Latitud',xlabel='Longitud',title='Distribución geográfica de los productos vendidos: Tienda 3')
# Out:
# <Axes: title={'center': 'Distribución geográfica de los productos vendidos: Tienda 3'}, xlabel='Longitud', ylabel='Latitud'>

# %%
ubicacion_tienda4=tienda4[['lat','lon']]
ubicacion_tienda4.plot(kind='scatter',x='lon',y='lat',ylabel='Latitud',xlabel='Longitud',title='Distribución geográfica de los productos vendidos: Tienda 4')
# Out:
# <Axes: title={'center': 'Distribución geográfica de los productos vendidos: Tienda 4'}, xlabel='Longitud', ylabel='Latitud'>

# %%
r1=tienda[['lat','lon']].value_counts()
r2=tienda2[['lat','lon']].value_counts()
r3=tienda3[['lat','lon']].value_counts()
r4=tienda4[['lat','lon']].value_counts()

union=pd.concat([r1,r2,r3,r4],axis=1)
union.columns=['Tienda 1','Tienda 2','Tienda 3','Tienda 4']
union['Total']=union.sum(axis=1)
union
# Out:
#                      Tienda 1  Tienda 2  Tienda 3  Tienda 4  Total
# lat       lon
#  4.60971  -74.08175       984       985       983       991   3943
#  6.25184  -75.56359       563       594       580       577   2314
#  3.43722  -76.52250       283       222       248       254   1007
#  4.81333  -75.69611       133       128       134       122    517
#  10.96854 -74.78132        75        78        77        80    310
#  10.39972 -75.51444        53        70        56        63    242
#  7.89391  -72.50782        51        59        44        32    186
#  11.54444 -72.90722        40        35        44        44    163
#  11.24079 -74.19904        32        40        44        35    151
# -4.21528  -69.94056        32        34        41        35    142
#  7.12539  -73.11980        31        50        50        50    181
#  1.21361  -77.28111        23        25        16        30     94
#  5.06889  -75.51738        15        13         7         6     41
# ...

# %% [markdown]
# #Informe Final

# %% [markdown]
# ##Introducción:
#
# El presente informe tiene el propósito de mostrar el análisis de eficiencia de cuatro tiendas de Alura Store pertenecientes al Sr. Juan. Para ello, se analizan variables como los ingresos totales, las ventas por categoría, la calificación de los clientes, los costos de envío, los productos más y menos vendidos y la distribución geográfica de los productos vendidos. Con base en toda la información reunida y estudiada, se dará una recomendación sobre cuál tienda es la mejor opción para vender.

# %% [markdown]
# ##Desarrollo:

# %%
print(f'Ingreso total tienda 1: {Ingreso_total_tienda_1}\nIngreso total tienda 2: {Ingreso_total_tienda_2}\nIngreso total tienda 3: {Ingreso_total_tienda_3}\nIngreso total tienda 4: {Ingreso_total_tienda_4} ')

Grafica=pd.DataFrame([['Tienda 1',Ingreso_total_tienda_1],['Tienda 2',Ingreso_total_tienda_2],['Tienda 3',Ingreso_total_tienda_3],['Tienda 4',Ingreso_total_tienda_4]],columns=['Tienda','Ingreso total'])
Grafica.plot(x='Tienda',kind='bar',color='green',xlabel='Tienda',ylabel='Ingreso',title='Ingreso total por tienda')
# Out:
# Ingreso total tienda 1: 1150880400.0
# Ingreso total tienda 2: 1116343500.0
# Ingreso total tienda 3: 1098019600.0
# Ingreso total tienda 4: 1038375700.0
# <Axes: title={'center': 'Ingreso total por tienda'}, xlabel='Tienda', ylabel='Ingreso'>

# %% [markdown]
# La tabla de ingresos totales muestra que la tienda 4 es la que menos factura y la Tienda 1 es la que más ingresos tiene. Las otras 2 tiendas presentan cantidadaes similares entre ellas.

# %%
Ventas_por_categoria_tienda_1.plot(kind='pie',color='red',ylabel='',title='Ventas por categoría: Tienda 1')
# Out:
# <Axes: title={'center': 'Ventas por categoría: Tienda 1'}>

# %%
Ventas_por_categoria_tienda_2.plot(kind='pie',color='red',ylabel='',title='Ventas por categoría: Tienda 2')
# Out:
# <Axes: title={'center': 'Ventas por categoría: Tienda 2'}>

# %%
Ventas_por_categoria_tienda_3.plot(kind='pie',color='red',ylabel='',title='Ventas por categoría: Tienda 3')
# Out:
# <Axes: title={'center': 'Ventas por categoría: Tienda 3'}>

# %%
Ventas_por_categoria_tienda_4.plot(kind='pie',color='red',ylabel='',title='Ventas por categoría: Tienda 4')
# Out:
# <Axes: title={'center': 'Ventas por categoría: Tienda 4'}>

# %% [markdown]
# Las ventas por categoría muestran que, en las cuatro tiendas, los productos más vendidos pertenecen al rubro de muebles, seguidos de los electrónicos y los juguetes. Además, los menos vendidos son, en general, los instrumentos musicales, los libros y los artículos para el hogar, aunque el orden de estos últimos varía dependiendo de la tienda.

# %%
print(f"Calificación promedio de las tiendas\nTienda 1: {Calificacion_Tienda_1}\nTienda 2: {Calificacion_Tienda_2}\nTienda 3: {Calificacion_Tienda_3}\nTienda 4: {Calificacion_Tienda_4}")
Calificacion_promedio=pd.DataFrame([['Tienda 1',Calificacion_Tienda_1],['Tienda 2',Calificacion_Tienda_2],['Tienda 3',Calificacion_Tienda_3],['Tienda 4',Calificacion_Tienda_4]],columns=['Tienda','Calificación promedio'])
Calificacion_promedio.plot(x='Tienda',title='Calificación promedio de cada tienda',ylabel='Calificación',marker='o')
# Out:
# Calificación promedio de las tiendas
# Tienda 1: 3.976685036032217
# Tienda 2: 4.037303942348453
# Tienda 3: 4.048325561678677
# Tienda 4: 3.9957591178965224
# <Axes: title={'center': 'Calificación promedio de cada tienda'}, xlabel='Tienda', ylabel='Calificación'>

# %% [markdown]
# En cuanto a la calificación promedio que los clientes dieron a cada tienda, se destaca que la de menor calificación fue la tienda 1, seguida de la tienda 4 por un margen mínimo. Las tiendas 2 y 3 presentan calificaciones más altas; sin embargo, si se analizan los valores brutos, se puede observar que las cuatro tiendas tienen calificaciones muy similares, alrededor de un valor de 4. Este dato es importante, ya que muestra que los clientes tienen una percepción similar del servicio y la calidad, independientemente de la tienda a la que acudan.

# %%
print("Productos menos vendidos tienda 1:\n",menos_vendidos_tienda1, "\n\nProductos más vendidos tienda 1:\n",mas_vendidos_tienda1)
print("Productos menos vendidos tienda 2:\n",menos_vendidos_tienda2, "\n\nProductos más vendidos tienda 2:\n",mas_vendidos_tienda2)
print("Productos menos vendidos tienda 3:\n",menos_vendidos_tienda3, "\n\nProductos más vendidos tienda 3:\n",mas_vendidos_tienda3)
print("Productos menos vendidos tienda 4:\n",menos_vendidos_tienda4, "\n\nProductos más vendidos tienda 4:\n",mas_vendidos_tienda4)
# Out:
# Productos menos vendidos tienda 1:
#                             count
# Producto
# Auriculares con micrófono     33
# Celular ABXY                  33
#
# Productos más vendidos tienda 1:
#                 count
# Producto
# Microondas        60
# TV LED UHD 4K     60
# Armario           60
# Productos menos vendidos tienda 2:
#                 count
# Producto
# Juego de mesa     32
#
# Productos más vendidos tienda 2:
#                             count
# Producto
# Iniciando en programación     65
# Productos menos vendidos tienda 3:
#                           count
# Producto
# Bloques de construcción     35
#
# Productos más vendidos tienda 3:
#                 count
# Producto
# Kit de bancas     57
# Productos menos vendidos tienda 4:
#                      count
# Producto
# Guitarra eléctrica     33
#
# Productos más vendidos tienda 4:
#            count
# Producto
# Cama box     62

# %% [markdown]
# Los datos anteriores muestran los productos más y menos vendidos de cada tienda; todos ellos son diferentes, lo que indica que, aunque por categoría las ventas se concentran en las tres mencionadas anteriormente, los artículos específicos que se venden son diversos. Esto también demuestra que cada tienda cuenta con sus propios productos destacados.

# %%
Envio_promedio_por_tienda.plot(color='black',x='Tienda',ylabel='Costo',title='Costo de envío de cada tienda',marker='o')
# Out:
# <Axes: title={'center': 'Costo de envío de cada tienda'}, xlabel='Tienda', ylabel='Costo'>

# %% [markdown]
# En cuanto a los envíos, la tienda 1 muestra el valor promedio más alto, mientras que la tienda 4 presenta el más bajo. Aunque este costo lo pague el cliente, es un indicador importante a considerar para mejorar el servicio y atraer a más personas. Es relevante señalar que, a pesar de que la tienda 1 presenta el costo de envío más elevado, también es la que más factura; por el contrario, la tienda 4 es la que menos factura, pero la que tiene el menor costo de envío.

# %%
ubicacion_tienda1=tienda[['lat','lon']]
ubicacion_tienda1.plot(kind='scatter',x='lon',y='lat',ylabel='Latitud',xlabel='Longitud',title='Distribución geográfica de los productos vendidos')
# Out:
# <Axes: title={'center': 'Distribución geográfica de los productos vendidos'}, xlabel='Longitud', ylabel='Latitud'>

# %%
r1=tienda[['lat','lon']].value_counts()
r2=tienda2[['lat','lon']].value_counts()
r3=tienda3[['lat','lon']].value_counts()
r4=tienda4[['lat','lon']].value_counts()

union=pd.concat([r1,r2,r3,r4],axis=1)
union.columns=['Tienda 1','Tienda 2','Tienda 3','Tienda 4']
union['Total']=union.sum(axis=1)
union
# Out:
#                      Tienda 1  Tienda 2  Tienda 3  Tienda 4  Total
# lat       lon
#  4.60971  -74.08175       984       985       983       991   3943
#  6.25184  -75.56359       563       594       580       577   2314
#  3.43722  -76.52250       283       222       248       254   1007
#  4.81333  -75.69611       133       128       134       122    517
#  10.96854 -74.78132        75        78        77        80    310
#  10.39972 -75.51444        53        70        56        63    242
#  7.89391  -72.50782        51        59        44        32    186
#  11.54444 -72.90722        40        35        44        44    163
#  11.24079 -74.19904        32        40        44        35    151
# -4.21528  -69.94056        32        34        41        35    142
#  7.12539  -73.11980        31        50        50        50    181
#  1.21361  -77.28111        23        25        16        30     94
#  5.06889  -75.51738        15        13         7         6     41
# ...

# %% [markdown]
# En cuanto a la distribución geográfica de las ventas, las cuatro tiendas presentan los mismos puntos de coordenadas, lo que da como resultado gráficas similares. Lo que cambia es la cantidad de veces que se repiten esas coordenadas en cada tienda. Sin embargo, el orden de importancia de estos puntos para cada tienda es prácticamente el mismo. Existen excepciones en algunas tiendas, donde ciertos puntos pueden cambiar de posición de acuerdo con la tabla anterior, pero la cantidad de ventas en esos casos es tan baja que no afecta la estadística general. Además, se observa claramente que existen cuatro puntos que concentran la mayoría de las compras; estos corresponden a los primeros cuatro puntos de la tabla anterior.

# %% [markdown]
# ##Conclusión:

# %% [markdown]
# De acuerdo con el análisis realizado de las cuatro tiendas, se recomienda vender la tienda 4, pues es la que tiene la menor cantidad total de facturación y la segunda peor calificación por parte de los clientes. Además, presenta un comportamiento en ventas por categoría y distribución geográfica similar al de las otras tiendas, lo que implica que su desaparición no afectaría drásticamente el desempeño general de las tres restantes.
#
# El único aspecto en el que destaca esta tienda es que tiene el menor costo de envío; sin embargo, esto no es suficiente para justificar su permanencia. En primer lugar, este costo lo asume el cliente y no la empresa, y además no representa un factor determinante que favorezca significativamente sus ingresos ni la satisfacción del cliente.
#
# Por lo tanto, con base en los puntos presentados anteriormente, mi recomendación es vender la tienda 4, si así es requerido.
